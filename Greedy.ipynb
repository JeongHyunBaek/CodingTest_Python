# %% [markdown]
# # 1이 될 때까지

# %%
n, k = map(int, input().split())
result = 0

while (True):
    target = (n // k )* k
    result += (n - target)
    n = target
    
    if (n < k):
        break
        
    result += 1
    n //= k

result += (n - 1)
print(result)
# Out:
# 25 5
# 2

# %% [markdown]
# # 곱하기 혹은 더하기

# %%
data = input()

result = int(data[0])

for i in range(1, len(data)):
    num = int(data[i])
    
    if num <= 1 or result <= 1:
        result += num
    else:
        result *= num

print(result)
# Out:
# 02984
# 576

# %% [markdown]
# # 모험가 길드

# %%
n = input()
data = list(map(int, input().split()))

data.sort()

result = 0
count = 0

for i in data:
    count += 1
    
    if count >= i:
        result += 1
        count = 0
        
print(result)
# Out:
# 5
# 2 3 1 2 2
# 2
